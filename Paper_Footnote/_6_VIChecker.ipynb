# %%
import os
import nbimporter

def back_to_root():
    root = os.getcwd()
    os.chdir(root)

# %%
import _1_git_repo_cloner as cloner

back_to_root()

# projectList.txt에 저장된 git repo path를 전부 clone 받음
project_list_file = "projectLIst.txt"
project_urls = cloner.get_repo_path(project_list_file)
# clone 받은 project 디렉토리명들을 project_list에 저장함
project_list = cloner.clone_project_and_update_gitignore(project_urls)
# Out:
# ['https://github.com/junit-team/junit4.git\n', 'https://github.com/h2database/h2database.git\n', 'https://github.com/google/gson.git\n', 'https://github.com/google/guava.git\n', 'https://github.com/bcgit/bc-java.git\n', 'https://github.com/pgjdbc/pgjdbc.git\n']
# junit4 프로젝트를 fetch하고, .gitignore를 업데이트했습니다.
# h2database 프로젝트를 fetch하고, .gitignore를 업데이트했습니다.
# gson 프로젝트를 fetch하고, .gitignore를 업데이트했습니다.
# guava 프로젝트를 fetch하고, .gitignore를 업데이트했습니다.
# bc-java 프로젝트를 fetch하고, .gitignore를 업데이트했습니다.
# pgjdbc 프로젝트를 fetch하고, .gitignore를 업데이트했습니다.
# 클론이 모두 완료되었습니다.

# %%
import _2_git_commit_logger as logger

back_to_root()

# commit-logs폴더에 json형식으로 커밋들의 정보를 저장
output_directory = "commit-logs"
if not os.path.exists(output_directory):
    os.makedirs(output_directory)
    
# commid_logger(project_list) # 현재 수작업
logger.add_changed_file_list(project_list, output_directory)

# %%
import _3_git_file_tracker as tracker

back_to_root()

# commit-files폴더에 커밋 시점의 수정된 java파일과 그 diff파일들을 저장
output_directory = "commit-files"
if not os.path.exists(output_directory):
    os.makedirs(output_directory)
    
tracker.file_tracker(project_list, output_directory)

# %%
# import openai
import _4_gpt_responser as responser

back_to_root()

# gpt-4 모델에 java/diff파일을 질의하여 응답을 {path}_response.txt에 저장
gpt_api_model = "gpt-4-0613"
openai.api_key = responser.get_api_key()

working_directory = "commit-files"
os.chdir(working_directory)

for directory in project_list:
    os.chdir(directory)
    responser.get_response_java_files(gpt_api_model)
    # responser.get_response_diff_files(gpt_api_model)
    os.chdir("..")
    
os.chdir("..")

# %%
import _5_save2sheet as storer

back_to_root()

# commit-sheets 폴더에 질의파일&응답쌍들을 엑셀파일에 저장
# 향후, google sheet에 자동으로 옮길 수 있으면 좋겠음
# 잘 저장되는지 주의 필요함!
output_directory = "commit-sheets"
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

working_directory = "commit-files"
os.chdir(working_directory)

for directory in project_list:
    os.chdir(directory)
    storer.commits_to_sheet(directory, output_directory, "after")
    os.chdir("..")
    
print("모든 작업이 완료되었습니다.")
os.chdir("..")
# Out:
# 1
# pgjdbc/src/main/java/org/postgresql/core/v3/ConnectionFactoryImpl.java
# File Open 오류: [Errno 2] No such file or directory: '1_after_pgjdbc_src_main_java_org_postgresql_core_v3_ConnectionFactoryImpl_response.txt'
# 2
# pgjdbc/src/main/java/org/postgresql/PGProperty.java
# File Open 오류: [Errno 2] No such file or directory: '2_after_pgjdbc_src_main_java_org_postgresql_PGProperty_response.txt'
# 3
# benchmarks/src/jmh/java/org/postgresql/benchmark/util/LongParser.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '3_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# pgjdbc/src/main/java/org/postgresql/util/NumberParser.java
# 4
# pgjdbc/src/main/java/org/postgresql/core/v3/QueryExecutorImpl.java
# File Open 오류: [Errno 2] No such file or directory: '4_after_pgjdbc_src_main_java_org_postgresql_core_v3_QueryExecutorImpl_response.txt'
# 5
# pgjdbc/src/main/java/org/postgresql/ds/common/BaseDataSource.java
# File Open 오류: [Errno 2] No such file or directory: '5_after_pgjdbc_src_main_java_org_postgresql_ds_common_BaseDataSource_response.txt'
# 6
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# File Open 오류: [Errno 2] No such file or directory: '6_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# 7
# pgjdbc/src/main/java/org/postgresql/jdbc/PgCallableStatement.java
# File Open 오류: [Errno 2] No such file or directory: '7_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgCallableStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgPreparedStatement.java
# File Open 오류: [Errno 2] No such file or directory: '7_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgPreparedStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '7_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# 8
# pgjdbc/src/main/java/org/postgresql/jdbc/PgStatement.java
# File Open 오류: [Errno 2] No such file or directory: '8_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgStatement_response.txt'
# 9
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '9_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnectionCleaningAction.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgStatement.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# File Open 오류: [Errno 2] No such file or directory: '9_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/QueryExecutorTimeZoneProvider.java
# pgjdbc/src/main/java/org/postgresql/jdbc/StatementCancelTimerTask.java
# pgjdbc/src/main/java/org/postgresql/util/LazyCleaner.java
# pgjdbc/src/main/java/org/postgresql/util/SharedTimer.java
# pgjdbc/src/main/java/org/postgresql/util/StreamWrapper.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/util/TempFileHolder.java
# 10
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '10_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnectionFinalizeAction.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgStatement.java
# File Open 오류: [Errno 2] No such file or directory: '10_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/QueryExecutorTimeZoneProvider.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/jdbc/StatementCancelTimerTask.java
# pgjdbc/src/main/java/org/postgresql/util/LazyCleaner.java
# pgjdbc/src/main/java/org/postgresql/util/SharedTimer.java
# pgjdbc/src/main/java/org/postgresql/util/StreamWrapper.java
# pgjdbc/src/main/java/org/postgresql/util/StreamWrapperFinalizeAction.java
# 11
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '11_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnectionCleaningAction.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgStatement.java
# File Open 오류: [Errno 2] No such file or directory: '11_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/QueryExecutorTimeZoneProvider.java
# pgjdbc/src/main/java/org/postgresql/jdbc/StatementCancelTimerTask.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/util/LazyCleaner.java
# pgjdbc/src/main/java/org/postgresql/util/SharedTimer.java
# pgjdbc/src/main/java/org/postgresql/util/StreamWrapper.java
# pgjdbc/src/main/java/org/postgresql/util/TempFileHolder.java
# 12
# pgjdbc/src/main/java/org/postgresql/core/Oid.java
# pgjdbc/src/main/java/org/postgresql/jdbc/TypeInfoCache.java
# File Open 오류: [Errno 2] No such file or directory: '12_after_pgjdbc_src_main_java_org_postgresql_jdbc_TypeInfoCache_response.txt'
# 13
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '13_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# 14
# pgjdbc/src/main/java/org/postgresql/core/QueryExecutor.java
# pgjdbc/src/main/java/org/postgresql/core/QueryExecutorBase.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/core/QueryExecutorCloseAction.java
# pgjdbc/src/main/java/org/postgresql/core/v3/QueryExecutorImpl.java
# File Open 오류: [Errno 2] No such file or directory: '14_after_pgjdbc_src_main_java_org_postgresql_core_v3_QueryExecutorImpl_response.txt'
# pgjdbc/src/main/java/org/postgresql/core/v3/SimpleParameterList.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '14_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnectionFinalizeAction.java
# pgjdbc/src/main/java/org/postgresql/util/StreamWrapper.java
# pgjdbc/src/main/java/org/postgresql/util/StreamWrapperFinalizeAction.java
# 15
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '15_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgDatabaseMetaData.java
# File Open 오류: [Errno 2] No such file or directory: '15_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgDatabaseMetaData_response.txt'
# pgjdbc/src/main/java/org/postgresql/largeobject/LargeObject.java
# pgjdbc/src/main/java/org/postgresql/largeobject/LargeObjectManager.java
# pgjdbc/src/main/java/org/postgresql/osgi/PGDataSourceFactory.java
# 16
# pgjdbc/src/main/java/org/postgresql/PGProperty.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# File Open 오류: [Errno 2] No such file or directory: '16_after_pgjdbc_src_main_java_org_postgresql_PGProperty_response.txt'
# pgjdbc/src/main/java/org/postgresql/core/PGStream.java
# pgjdbc/src/main/java/org/postgresql/core/QueryExecutorBase.java
# pgjdbc/src/main/java/org/postgresql/core/v3/QueryExecutorImpl.java
# File Open 오류: [Errno 2] No such file or directory: '16_after_pgjdbc_src_main_java_org_postgresql_core_v3_QueryExecutorImpl_response.txt'
# pgjdbc/src/main/java/org/postgresql/geometric/PGbox.java
# pgjdbc/src/main/java/org/postgresql/geometric/PGcircle.java
# pgjdbc/src/main/java/org/postgresql/geometric/PGline.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/geometric/PGlseg.java
# pgjdbc/src/main/java/org/postgresql/geometric/PGpath.java
# pgjdbc/src/main/java/org/postgresql/geometric/PGpoint.java
# pgjdbc/src/main/java/org/postgresql/geometric/PGpolygon.java
# pgjdbc/src/main/java/org/postgresql/gss/MakeGSS.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgArray.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '16_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgDatabaseMetaData.java
# File Open 오류: [Errno 2] No such file or directory: '16_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgDatabaseMetaData_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgPreparedStatement.java
# File Open 오류: [Errno 2] No such file or directory: '16_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgPreparedStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgStatement.java
# File Open 오류: [Errno 2] No such file or directory: '16_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/TypeInfoCache.java
# File Open 오류: [Errno 2] No such file or directory: '16_after_pgjdbc_src_main_java_org_postgresql_jdbc_TypeInfoCache_response.txt'
# pgjdbc/src/main/java/org/postgresql/jre7/sasl/ScramAuthenticator.java
# pgjdbc/src/main/java/org/postgresql/osgi/PGDataSourceFactory.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/ssl/DbKeyStoreSocketFactory.java
# pgjdbc/src/main/java/org/postgresql/ssl/WrappedFactory.java
# pgjdbc/src/main/java/org/postgresql/util/LogWriterHandler.java
# pgjdbc/src/main/java/org/postgresql/util/PGInterval.java
# pgjdbc/src/main/java/org/postgresql/util/PGmoney.java
# pgjdbc/src/main/java/org/postgresql/util/PGtokenizer.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/util/internal/Nullness.java
# 17
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '17_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# 18
# pgjdbc/src/main/java/org/postgresql/Driver.java
# File Open 오류: [Errno 2] No such file or directory: '18_after_pgjdbc_src_main_java_org_postgresql_Driver_response.txt'
# pgjdbc/src/main/java/org/postgresql/core/QueryExecutorBase.java
# pgjdbc/src/main/java/org/postgresql/core/v3/CopyOperationImpl.java
# pgjdbc/src/main/java/org/postgresql/core/v3/QueryExecutorImpl.java
# File Open 오류: [Errno 2] No such file or directory: '18_after_pgjdbc_src_main_java_org_postgresql_core_v3_QueryExecutorImpl_response.txt'
# pgjdbc/src/main/java/org/postgresql/ds/PGPoolingDataSource.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/hostchooser/GlobalHostStatusTracker.java
# pgjdbc/src/main/java/org/postgresql/jdbc/AbstractBlobClob.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgArray.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgBlob.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgCallableStatement.java
# File Open 오류: [Errno 2] No such file or directory: '18_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgCallableStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgClob.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '18_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgPreparedStatement.java
# File Open 오류: [Errno 2] No such file or directory: '18_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgPreparedStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '18_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgSQLXML.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgStatement.java
# File Open 오류: [Errno 2] No such file or directory: '18_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/ResourceLock.java
# pgjdbc/src/main/java/org/postgresql/jdbc/TimestampUtils.java
# File Open 오류: [Errno 2] No such file or directory: '18_after_pgjdbc_src_main_java_org_postgresql_jdbc_TimestampUtils_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/TypeInfoCache.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# File Open 오류: [Errno 2] No such file or directory: '18_after_pgjdbc_src_main_java_org_postgresql_jdbc_TypeInfoCache_response.txt'
# pgjdbc/src/main/java/org/postgresql/largeobject/BlobInputStream.java
# pgjdbc/src/main/java/org/postgresql/ssl/PKCS12KeyManager.java
# pgjdbc/src/main/java/org/postgresql/util/LogWriterHandler.java
# pgjdbc/src/main/java/org/postgresql/util/LruCache.java
# pgjdbc/src/main/java/org/postgresql/util/SharedTimer.java
# 19
# pgjdbc/src/main/java/org/postgresql/core/QueryExecutor.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/core/v3/QueryExecutorImpl.java
# File Open 오류: [Errno 2] No such file or directory: '19_after_pgjdbc_src_main_java_org_postgresql_core_v3_QueryExecutorImpl_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '19_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# 20
# pgjdbc/src/main/java/org/postgresql/PGProperty.java
# File Open 오류: [Errno 2] No such file or directory: '20_after_pgjdbc_src_main_java_org_postgresql_PGProperty_response.txt'
# 21
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '21_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# 22
# pgjdbc/src/main/java/org/postgresql/core/BaseConnection.java
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '22_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '22_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# 23
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '23_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# 24
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '24_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# 25
# pgjdbc/src/main/java/org/postgresql/core/Parser.java
# File Open 오류: [Errno 2] No such file or directory: '25_after_pgjdbc_src_main_java_org_postgresql_core_Parser_response.txt'
# 26
# pgjdbc/src/main/java/org/postgresql/core/v3/ConnectionFactoryImpl.java
# File Open 오류: [Errno 2] No such file or directory: '26_after_pgjdbc_src_main_java_org_postgresql_core_v3_ConnectionFactoryImpl_response.txt'
# 27
# pgjdbc/src/main/java/org/postgresql/core/ConnectionFactory.java
# 28
# pgjdbc/src/main/java/org/postgresql/core/v3/ConnectionFactoryImpl.java
# File Open 오류: [Errno 2] No such file or directory: '28_after_pgjdbc_src_main_java_org_postgresql_core_v3_ConnectionFactoryImpl_response.txt'
# 29
# pgjdbc/src/main/java/org/postgresql/jdbc/PgConnection.java
# File Open 오류: [Errno 2] No such file or directory: '29_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgConnection_response.txt'
# 30
# pgjdbc/src/main/java/org/postgresql/util/ByteConverter.java
# 31
# pgjdbc/src/main/java/org/postgresql/PGProperty.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# File Open 오류: [Errno 2] No such file or directory: '31_after_pgjdbc_src_main_java_org_postgresql_PGProperty_response.txt'
# 32
# pgjdbc/src/main/java/org/postgresql/core/Oid.java
# 33
# pgjdbc/src/main/java/org/postgresql/PGProperty.java
# File Open 오류: [Errno 2] No such file or directory: '33_after_pgjdbc_src_main_java_org_postgresql_PGProperty_response.txt'
# pgjdbc/src/main/java/org/postgresql/core/v3/ConnectionFactoryImpl.java
# File Open 오류: [Errno 2] No such file or directory: '33_after_pgjdbc_src_main_java_org_postgresql_core_v3_ConnectionFactoryImpl_response.txt'
# pgjdbc/src/main/java/org/postgresql/ds/common/BaseDataSource.java
# File Open 오류: [Errno 2] No such file or directory: '33_after_pgjdbc_src_main_java_org_postgresql_ds_common_BaseDataSource_response.txt'
# 34
# pgjdbc/src/main/java/org/postgresql/PGProperty.java
# File Open 오류: [Errno 2] No such file or directory: '34_after_pgjdbc_src_main_java_org_postgresql_PGProperty_response.txt'
# 35
# pgjdbc/src/main/java/org/postgresql/core/PGStream.java
# pgjdbc/src/main/java/org/postgresql/util/StreamWrapper.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# 36
# pgjdbc/src/main/java/org/postgresql/util/StreamWrapper.java
# 37
# pgjdbc/src/main/java/org/postgresql/PGProperty.java
# File Open 오류: [Errno 2] No such file or directory: '37_after_pgjdbc_src_main_java_org_postgresql_PGProperty_response.txt'
# 38
# pgjdbc/src/main/java/org/postgresql/largeobject/LargeObject.java
# pgjdbc/src/main/java/org/postgresql/replication/PGReplicationStream.java
# 39
# pgjdbc/src/main/java/org/postgresql/PGProperty.java
# File Open 오류: [Errno 2] No such file or directory: '39_after_pgjdbc_src_main_java_org_postgresql_PGProperty_response.txt'
# 40
# pgjdbc/src/main/java/org/postgresql/Driver.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# ...
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/util/PGPropertyPasswordParser.java
# pgjdbc/src/main/java/org/postgresql/util/PGPropertyServiceParser.java
# pgjdbc/src/main/java/org/postgresql/util/PGPropertyUtil.java
# 114
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '114_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/TimestampUtils.java
# File Open 오류: [Errno 2] No such file or directory: '114_after_pgjdbc_src_main_java_org_postgresql_jdbc_TimestampUtils_response.txt'
# 115
# pgjdbc/src/main/java/org/postgresql/core/v3/ConnectionFactoryImpl.java
# File Open 오류: [Errno 2] No such file or directory: '115_after_pgjdbc_src_main_java_org_postgresql_core_v3_ConnectionFactoryImpl_response.txt'
# pgjdbc/src/main/java/org/postgresql/core/v3/QueryExecutorImpl.java
# File Open 오류: [Errno 2] No such file or directory: '115_after_pgjdbc_src_main_java_org_postgresql_core_v3_QueryExecutorImpl_response.txt'
# 116
# pgjdbc/src/main/java/org/postgresql/jdbc/PgStatement.java
# File Open 오류: [Errno 2] No such file or directory: '116_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgStatement_response.txt'
# 117
# pgjdbc/src/main/java/org/postgresql/jdbc/PgCallableStatement.java
# File Open 오류: [Errno 2] No such file or directory: '117_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgCallableStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgPreparedStatement.java
# File Open 오류: [Errno 2] No such file or directory: '117_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgPreparedStatement_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '117_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgStatement.java
# File Open 오류: [Errno 2] No such file or directory: '117_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgStatement_response.txt'
# 118
# pgjdbc/src/main/java/org/postgresql/util/ByteConverter.java
# 119
# pgjdbc/src/main/java/org/postgresql/core/OptimizedUTF8Encoder.java
# 120
# pgjdbc/src/main/java/org/postgresql/util/ByteConverter.java
# 121
# pgjdbc/src/main/java/org/postgresql/core/AsciiStringInterner.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/core/Encoding.java
# pgjdbc/src/main/java/org/postgresql/core/PGStream.java
# pgjdbc/src/main/java/org/postgresql/core/v3/QueryExecutorImpl.java
# File Open 오류: [Errno 2] No such file or directory: '121_after_pgjdbc_src_main_java_org_postgresql_core_v3_QueryExecutorImpl_response.txt'
# 122
# pgjdbc/src/main/java/org/postgresql/util/PGbytea.java
# 123
# pgjdbc/src/main/java/org/postgresql/core/QueryExecutorBase.java
# 124
# pgjdbc/src/main/java/org/postgresql/core/ByteOptimizedUTF8Encoder.java
# pgjdbc/src/main/java/org/postgresql/core/CharOptimizedUTF8Encoder.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/core/Encoding.java
# 125
# pgjdbc/src/main/java/org/postgresql/jdbc/ArrayEncoding.java
# File Open 오류: [Errno 2] No such file or directory: '125_after_pgjdbc_src_main_java_org_postgresql_jdbc_ArrayEncoding_response.txt'
# 126
# pgjdbc/src/main/java/org/postgresql/jdbc/TimestampUtils.java
# File Open 오류: [Errno 2] No such file or directory: '126_after_pgjdbc_src_main_java_org_postgresql_jdbc_TimestampUtils_response.txt'
# 127
# pgjdbc/src/main/java/org/postgresql/core/v3/ConnectionFactoryImpl.java
# File Open 오류: [Errno 2] No such file or directory: '127_after_pgjdbc_src_main_java_org_postgresql_core_v3_ConnectionFactoryImpl_response.txt'
# 128
# pgjdbc/src/main/java/org/postgresql/core/TypeInfo.java
# pgjdbc/src/main/java/org/postgresql/jdbc/TypeInfoCache.java
# File Open 오류: [Errno 2] No such file or directory: '128_after_pgjdbc_src_main_java_org_postgresql_jdbc_TypeInfoCache_response.txt'
# 129
# pgjdbc/src/main/java/org/postgresql/PGProperty.java
# File Open 오류: [Errno 2] No such file or directory: '129_after_pgjdbc_src_main_java_org_postgresql_PGProperty_response.txt'
# pgjdbc/src/main/java/org/postgresql/core/CachedQueryCreateAction.java
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc/src/main/java/org/postgresql/core/Parser.java
# File Open 오류: [Errno 2] No such file or directory: '129_after_pgjdbc_src_main_java_org_postgresql_core_Parser_response.txt'
# pgjdbc/src/main/java/org/postgresql/core/QueryExecutor.java
# pgjdbc/src/main/java/org/postgresql/core/QueryExecutorBase.java
# pgjdbc/src/main/java/org/postgresql/core/v3/QueryExecutorImpl.java
# File Open 오류: [Errno 2] No such file or directory: '129_after_pgjdbc_src_main_java_org_postgresql_core_v3_QueryExecutorImpl_response.txt'
# pgjdbc/src/main/java/org/postgresql/ds/common/BaseDataSource.java
# File Open 오류: [Errno 2] No such file or directory: '129_after_pgjdbc_src_main_java_org_postgresql_ds_common_BaseDataSource_response.txt'
# 130
# pgjdbc/src/main/java/org/postgresql/jdbc/PgDatabaseMetaData.java
# File Open 오류: [Errno 2] No such file or directory: '130_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgDatabaseMetaData_response.txt'
# pgjdbc/src/main/java/org/postgresql/jdbc/PgResultSet.java
# File Open 오류: [Errno 2] No such file or directory: '130_after_pgjdbc_src_main_java_org_postgresql_jdbc_PgResultSet_response.txt'
# 131
# pgjdbc/src/main/java/org/postgresql/core/Oid.java
# pgjdbc/src/main/java/org/postgresql/jdbc/ArrayDecoding.java
# 132
# pgjdbc/src/main/java/org/postgresql/core/v3/QueryExecutorImpl.java
# File Open 오류: [Errno 2] No such file or directory: '132_after_pgjdbc_src_main_java_org_postgresql_core_v3_QueryExecutorImpl_response.txt'
# pgjdbc/src/main/java/org/postgresql/util/PSQLState.java
# 133
# pgjdbc/src/main/java/org/postgresql/PGProperty.java
# File Open 오류: [Errno 2] No such file or directory: '133_after_pgjdbc_src_main_java_org_postgresql_PGProperty_response.txt'
# 134
# pgjdbc/src/main/java/org/postgresql/jdbc/TypeInfoCache.java
# File Open 오류: [Errno 2] No such file or directory: '134_after_pgjdbc_src_main_java_org_postgresql_jdbc_TypeInfoCache_response.txt'
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# _5_save2sheet.ipynb:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   "            response_content = read_file(response_file_path)\n",
# pgjdbc 데이터가 엑셀 파일에 저장되었습니다.
# 모든 작업이 완료되었습니다.

# %%
back_to_root()

# %%
os.getcwd()
# Out:
# 'C:\\Users\\bjh17\\Jupyter\\VIChecker'

# %%
print(project_list)
# Out:
# ['pgjdbc']

# %%
os.chdir("..")

# %%
project_list = ["pgjdbc"]
